# %% [markdown]
# <a href="https://colab.research.google.com/github/Chaitanya081/DSA0410_Fundamentals-of-Data-Science-Lab-Experiments/blob/main/EXP_35_Write_a_Python_Program_to_build_a_clustering_model_using_the_K_Means_algorithm_to_group_customers_into_distinct_segments_based_on_their_spending_patterns_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("retail_customers.csv")
print("Dataset Preview:")
print(df.head())
# Out:
# Dataset Preview:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %%
# Select spending-related features
X = df[['Fresh', 'Milk', 'Grocery', 'Frozen',
        'Detergents_Paper', 'Delicassen']]

# Feature scaling (VERY IMPORTANT)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply K-Means clustering
kmeans = KMeans(n_clusters=3, random_state=42)
df['Cluster'] = kmeans.fit_predict(X_scaled)

# Display clustered customers
print("\nCustomer Segments:")
print(df[['Cluster']].value_counts())
# Out:
# Customer Segments:
# Cluster
# 0          350
# 1           53
# 2           37
# Name: count, dtype: int64

# %%
# -------- USER INPUT --------
print("\nEnter new customer spending details:")
fresh = float(input("Fresh spending: "))
milk = float(input("Milk spending: "))
grocery = float(input("Grocery spending: "))
frozen = float(input("Frozen spending: "))
detergents = float(input("Detergents & Paper spending: "))
delicassen = float(input("Delicassen spending: "))
# Out:
# Enter new customer spending details:
# Fresh spending: 12000
# Milk spending: 6000
# Grocery spending: 8000
# Frozen spending: 2000
# Detergents & Paper spending: 3000
# Delicassen spending: 1000

# %%
new_customer_df = pd.DataFrame(
    [[fresh, milk, grocery, frozen, detergents, delicassen]],
    columns=['Fresh', 'Milk', 'Grocery', 'Frozen',
             'Detergents_Paper', 'Delicassen']
)
new_customer_scaled = scaler.transform(new_customer_df)
cluster = kmeans.predict(new_customer_scaled)

print("\nThe new customer belongs to Segment:", cluster[0])
# Out:
# The new customer belongs to Segment: 0
