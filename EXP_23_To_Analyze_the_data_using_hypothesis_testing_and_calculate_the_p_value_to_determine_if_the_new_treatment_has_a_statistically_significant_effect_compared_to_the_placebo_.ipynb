# %% [markdown]
# <a href="https://colab.research.google.com/github/Chaitanya081/DSA0410_Fundamentals-of-Data-Science-Lab-Experiments/blob/main/EXP_23_To_Analyze_the_data_using_hypothesis_testing_and_calculate_the_p_value_to_determine_if_the_new_treatment_has_a_statistically_significant_effect_compared_to_the_placebo_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind

# %%
df = pd.read_csv("diabetes.csv")

# %%
control_group = df[df["Outcome"] == 0]["Glucose"]
treatment_group = df[df["Outcome"] == 1]["Glucose"]

# %%
t_stat, p_value = ttest_ind(control_group, treatment_group)
print("T-statistic:", t_stat)
print("P-value:", p_value)
# Out:
# T-statistic: -14.600060005973894
# P-value: 8.935431645289912e-43

# %%
plt.boxplot([control_group, treatment_group],
            labels=["Control (Placebo)", "Treatment (Drug)"])
plt.title("Effect of Treatment on Glucose Levels")
plt.ylabel("Glucose Level")
plt.text(1.5, max(df["Glucose"]), f"P-value = {p_value:.5f}", ha="center")
plt.show()
# Out:
# /tmp/ipython-input-2741302628.py:1: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([control_group, treatment_group],
